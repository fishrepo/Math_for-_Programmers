# %%
from vector_drawing import *
from vectors import *

# %%
dino_vectors = [(6,4), (3,1), (1,2), (-1,5), (-2,5), (-3,4), (-4,4),
    (-5,3), (-5,2), (-2,2), (-5,1), (-4,0), (-2,1), (-1,0), (0,-3),
    (-1,-4), (1,-4), (2,-3), (1,-2), (3,-1), (5,1)
]

# %%
draw(Points(*dino_vectors))

# %%
draw(Points(*dino_vectors),Segment((6,4),(3,1)),Segment((3,1),(1,2)))

# %%
draw(Points(*[(x,x**2) for x in range(-10,11)]),grid=(1,10),nice_aspect_ratio=False)

# %%
dino_vectors2 = [add((-1.5,-2.5),v) for v in dino_vectors]

my = [add((1,1),[[2,2],[3,3]])]

draw(Points(*my))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Math_for_Programmers\two-dimensional-vetor\math.ipynb Cell 6 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Math_for_Programmers/two-dimensional-vetor/math.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> dino_vectors2 = [add((-1.5,-2.5),v) for v in dino_vectors]
# ----> <a href='vscode-notebook-cell:/c%3A/Math_for_Programmers/two-dimensional-vetor/math.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> my = [add((1,1),[[2,2],[3,3]])]
#       <a href='vscode-notebook-cell:/c%3A/Math_for_Programmers/two-dimensional-vetor/math.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a> draw(Points(*my))
#
# File c:\Math_for_Programmers\two-dimensional-vetor\vectors.py:10, in add(*vectors)
#       9 def add(*vectors):
# ---> 10     return (sum([v[0] for v in vectors]), sum([v[1] for v in vectors]))
#
# TypeError: unsupported operand type(s) for +: 'int' and 'list'

# %%
dino_vectors2 = [add((-1.5,-2.5),v) for v in dino_vectors]

draw(Points(*dino_vectors,color=blue),
     Polygon(*dino_vectors, color=blue),
     Points(*dino_vectors2, color=red),
     Polygon(*dino_vectors2,color=red))

# %%
length((3,4))
# Out:
# 5.0

# %%
a= add((-2,0),(1.5,1.5))

# %%
b = add(a,(4,1))

# %%
b
# Out:
# (3.5, 2.5)

# %%
from math import *

tan(pi/4)
# Out:
# 0.9999999999999999

# %%
atan2(1,0)
# Out:
# 1.5707963267948966

# %%
to_polar((-1.34,2.68))
# Out:
# (2.9963310898497184, 2.0344439357957027)

# %%
15*sin(radians(37))
# Out:
# 9.027225347280725

# %%
15*cos(radians(37))
# Out:
# 11.979532650709393

# %%
x,y = 15*cos(radians(37)),15*sin(radians(37))

# %%
x,y
# Out:
# (11.979532650709393, 9.027225347280725)

# %%
degrees(atan2(3,-2))
# Out:
# 123.69006752597979

# %%
small_dino = [(x[0]*0.5,x[1]*0.5) for x in dino_vectors]

# %%
draw(Points(*dino_vectors))

# %%
draw(Points(*small_dino))
